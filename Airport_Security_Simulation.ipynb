# %% [markdown]
# # Airport Security Simulation

# %% [markdown]
# This notebook includes:
# * Using SimPy to simulate Airport Security and determine optimal number of ID Check Stations and Personal Scanners to reduce wait times to under 15 minutes
# * NOTE: Arrival Time and Simulation Time have been decreased to reduce computational resources

# %%
import random
import simpy
import numpy as np

# %%
#Passengers arrive (according to poisson distribution) and go through ID Check (exponential service time)
#Passengers assigned to shortest personal check queue, personal scanner (uniformly distributed)
#Passenger leaves

# %%
# Set seed to reproduce results
RANDOM_SEED = 18

# Number of ID Check Stations
NUM_ID_CHECK = 4      

# Number of Personal Scanners
NUM_SCANNER = 2       

# Create a passenger based on poisson distribution (lam = 0.2) or 5 passengers/minute
ARRIVAL_TIME = 0.2

# Create time for ID Check Station based on exponential distribution (lam = 0.75)
ID_CHECK_TIME = 0.75       

# Simulation time in minutes
SIM_TIME = 240

# Create list to calculate and track wait times.
wait_times = []

# %%
class AirportSecurity(object):
    """An ID Check Station has a limited number of stations (``NUM_ID_CHECK``) to
    check IDs.

    Passengers have to request one of the stations. When they get one, they
    can start the ID Check process and wait for it to finish (which
    takes ``ID_CHECK_TIME`` minutes).

    """
    def __init__(self, env, num_id_check, id_check_time, num_scanner):
        self.env = env
        self.station = simpy.Resource(env, num_id_check)
        self.id_check_time = id_check_time
        self.personal_scanner = simpy.Resource(env, num_scanner)
        

    def id_check(self, passenger):
        """The ID Check process. It takes a ``passenger`` and checks their ID/Boarding Pass."""
        yield self.env.timeout(np.random.poisson(lam = ID_CHECK_TIME))
        print("%s's ID/Boarding Pass has been checked and verified." %
              passenger)
        
    def scanner(self, passenger):
        """The Personal Scanner process. It takes a ``passenger`` and the passenger goes 
        through a personal scanner"""
        yield self.env.timeout(np.random.uniform(low = 0.5, high = 1.0))
        print("%s completes personal scanning process." %
              passenger)

# %%
def passenger(env, name, aps):
    """The passenger process (each paseenger has a ``name``) arrives at the airport security
    (``aps``) and requests an ID Check Station, goes through a Personal Scanner, and leaves 
    the Airport Security environment.
    """
    print('%s arrives at the Airport Security at %.2f.' % (name, env.now))
    start = env.now
    with aps.station.request() as request:
        yield request

        print('%s enters ID Check Station at %.2f.' % (name, env.now))
        yield env.process(aps.id_check(name))
        
    with aps.personal_scanner.request() as request:
        print('%s enters Personal Scanner at %.2f.' % (name, env.now))
        yield env.process(aps.scanner(name))
    
    print('%s leaves Airport Security at %.2f.' % (name, env.now))
    wait_times.append(env.now - start)

# %%
def setup(env, num_id_check, id_check_time, num_scanner, arrival_time):
    """Create an airport security environment and create passengers
    approx. every ``arrival_time`` minutes."""
    # Create the airport security environment
    airport_security = AirportSecurity(env, num_id_check, id_check_time, num_scanner)
    
    # Create passengers while the simulation is running
    i = 0
    while True:
        yield env.timeout(np.random.poisson(lam=ARRIVAL_TIME))
        i += 1
        env.process(passenger(env, 'Passenger %d' % i, airport_security))

# %%
# Setup and start the simulation
print('Airport Security')
random.seed(RANDOM_SEED)  # Helps reproduce results

# Create an environment and start the setup process
env = simpy.Environment()
env.process(setup(env, NUM_ID_CHECK, ID_CHECK_TIME, NUM_SCANNER, ARRIVAL_TIME))

# Execute!
env.run(until=SIM_TIME)
# Out:
# Airport Security
# Passenger 1 arrives at the Airport Security at 0.00.
# Passenger 2 arrives at the Airport Security at 0.00.
# Passenger 1 enters ID Check Station at 0.00.
# Passenger 3 arrives at the Airport Security at 0.00.
# Passenger 2 enters ID Check Station at 0.00.
# Passenger 1's ID/Boarding Pass has been checked and verified.
# Passenger 4 arrives at the Airport Security at 0.00.
# Passenger 3 enters ID Check Station at 0.00.
# Passenger 2's ID/Boarding Pass has been checked and verified.
# Passenger 1 enters Personal Scanner at 0.00.
# Passenger 5 arrives at the Airport Security at 0.00.
# Passenger 4 enters ID Check Station at 0.00.
# Passenger 3's ID/Boarding Pass has been checked and verified.
# Passenger 2 enters Personal Scanner at 0.00.
# Passenger 6 arrives at the Airport Security at 0.00.
# Passenger 5 enters ID Check Station at 0.00.
# Passenger 4's ID/Boarding Pass has been checked and verified.
# Passenger 3 enters Personal Scanner at 0.00.
# Passenger 7 arrives at the Airport Security at 0.00.
# Passenger 6 enters ID Check Station at 0.00.
# Passenger 4 enters Personal Scanner at 0.00.
# Passenger 8 arrives at the Airport Security at 0.00.
# Passenger 7 enters ID Check Station at 0.00.
# Passenger 6's ID/Boarding Pass has been checked and verified.
# Passenger 9 arrives at the Airport Security at 0.00.
# Passenger 8 enters ID Check Station at 0.00.
# Passenger 6 enters Personal Scanner at 0.00.
# Passenger 10 arrives at the Airport Security at 0.00.
# Passenger 11 arrives at the Airport Security at 0.00.
# Passenger 9 enters ID Check Station at 0.00.
# Passenger 12 arrives at the Airport Security at 0.00.
# Passenger 13 arrives at the Airport Security at 0.00.
# Passenger 14 arrives at the Airport Security at 0.00.
# Passenger 2 completes personal scanning process.
# Passenger 2 leaves Airport Security at 0.60.
# Passenger 1 completes personal scanning process.
# Passenger 1 leaves Airport Security at 0.61.
# Passenger 3 completes personal scanning process.
# Passenger 3 leaves Airport Security at 0.67.
# Passenger 6 completes personal scanning process.
# Passenger 6 leaves Airport Security at 0.82.
# Passenger 4 completes personal scanning process.
# Passenger 4 leaves Airport Security at 0.98.
# Passenger 5's ID/Boarding Pass has been checked and verified.
# Passenger 7's ID/Boarding Pass has been checked and verified.
# Passenger 8's ID/Boarding Pass has been checked and verified.
# Passenger 9's ID/Boarding Pass has been checked and verified.
# Passenger 15 arrives at the Airport Security at 1.00.
# Passenger 5 enters Personal Scanner at 1.00.
# Passenger 7 enters Personal Scanner at 1.00.
# Passenger 8 enters Personal Scanner at 1.00.
# Passenger 9 enters Personal Scanner at 1.00.
# Passenger 16 arrives at the Airport Security at 1.00.
# Passenger 17 arrives at the Airport Security at 1.00.
# Passenger 10 enters ID Check Station at 1.00.
# Passenger 11 enters ID Check Station at 1.00.
# Passenger 12 enters ID Check Station at 1.00.
# Passenger 13 enters ID Check Station at 1.00.
# Passenger 18 arrives at the Airport Security at 1.00.
# Passenger 10's ID/Boarding Pass has been checked and verified.
# Passenger 11's ID/Boarding Pass has been checked and verified.
# Passenger 12's ID/Boarding Pass has been checked and verified.
# Passenger 13's ID/Boarding Pass has been checked and verified.
# Passenger 19 arrives at the Airport Security at 1.00.
# Passenger 10 enters Personal Scanner at 1.00.
# Passenger 11 enters Personal Scanner at 1.00.
# Passenger 12 enters Personal Scanner at 1.00.
# Passenger 13 enters Personal Scanner at 1.00.
# Passenger 20 arrives at the Airport Security at 1.00.
# Passenger 21 arrives at the Airport Security at 1.00.
# Passenger 14 enters ID Check Station at 1.00.
# Passenger 15 enters ID Check Station at 1.00.
# Passenger 16 enters ID Check Station at 1.00.
# Passenger 17 enters ID Check Station at 1.00.
# Passenger 22 arrives at the Airport Security at 1.00.
# Passenger 14's ID/Boarding Pass has been checked and verified.
# Passenger 15's ID/Boarding Pass has been checked and verified.
# Passenger 16's ID/Boarding Pass has been checked and verified.
# Passenger 23 arrives at the Airport Security at 1.00.
# Passenger 14 enters Personal Scanner at 1.00.
# Passenger 15 enters Personal Scanner at 1.00.
# Passenger 16 enters Personal Scanner at 1.00.
# Passenger 24 arrives at the Airport Security at 1.00.
# Passenger 25 arrives at the Airport Security at 1.00.
# Passenger 18 enters ID Check Station at 1.00.
# Passenger 19 enters ID Check Station at 1.00.
# Passenger 20 enters ID Check Station at 1.00.
# Passenger 26 arrives at the Airport Security at 1.00.
# Passenger 20's ID/Boarding Pass has been checked and verified.
# Passenger 20 enters Personal Scanner at 1.00.
# Passenger 21 enters ID Check Station at 1.00.
# Passenger 21's ID/Boarding Pass has been checked and verified.
# Passenger 21 enters Personal Scanner at 1.00.
# Passenger 22 enters ID Check Station at 1.00.
# Passenger 15 completes personal scanning process.
# Passenger 15 leaves Airport Security at 1.51.
# Passenger 8 completes personal scanning process.
# Passenger 8 leaves Airport Security at 1.54.
# Passenger 11 completes personal scanning process.
# Passenger 11 leaves Airport Security at 1.55.
# Passenger 14 completes personal scanning process.
# Passenger 14 leaves Airport Security at 1.57.
# Passenger 21 completes personal scanning process.
# Passenger 21 leaves Airport Security at 1.61.
# Passenger 9 completes personal scanning process.
# Passenger 9 leaves Airport Security at 1.62.
# Passenger 5 completes personal scanning process.
# Passenger 5 leaves Airport Security at 1.64.
# Passenger 7 completes personal scanning process.
# Passenger 7 leaves Airport Security at 1.66.
# Passenger 13 completes personal scanning process.
# Passenger 13 leaves Airport Security at 1.70.
# Passenger 16 completes personal scanning process.
# Passenger 16 leaves Airport Security at 1.71.
# Passenger 12 completes personal scanning process.
# Passenger 12 leaves Airport Security at 1.75.
# Passenger 20 completes personal scanning process.
# Passenger 20 leaves Airport Security at 1.84.
# Passenger 10 completes personal scanning process.
# Passenger 10 leaves Airport Security at 1.93.
# Passenger 18's ID/Boarding Pass has been checked and verified.
# Passenger 19's ID/Boarding Pass has been checked and verified.
# Passenger 27 arrives at the Airport Security at 2.00.
# Passenger 18 enters Personal Scanner at 2.00.
# Passenger 19 enters Personal Scanner at 2.00.
# Passenger 23 enters ID Check Station at 2.00.
# Passenger 24 enters ID Check Station at 2.00.
# Passenger 23's ID/Boarding Pass has been checked and verified.
# Passenger 23 enters Personal Scanner at 2.00.
# Passenger 25 enters ID Check Station at 2.00.
# Passenger 25's ID/Boarding Pass has been checked and verified.
# Passenger 25 enters Personal Scanner at 2.00.
# Passenger 26 enters ID Check Station at 2.00.
# Passenger 26's ID/Boarding Pass has been checked and verified.
# Passenger 26 enters Personal Scanner at 2.00.
# Passenger 27 enters ID Check Station at 2.00.
# Passenger 27's ID/Boarding Pass has been checked and verified.
# Passenger 27 enters Personal Scanner at 2.00.
# Passenger 23 completes personal scanning process.
# Passenger 23 leaves Airport Security at 2.63.
# Passenger 25 completes personal scanning process.
# Passenger 25 leaves Airport Security at 2.74.
# Passenger 19 completes personal scanning process.
# Passenger 19 leaves Airport Security at 2.77.
# Passenger 26 completes personal scanning process.
# Passenger 26 leaves Airport Security at 2.83.
# Passenger 27 completes personal scanning process.
# Passenger 27 leaves Airport Security at 2.85.
# Passenger 18 completes personal scanning process.
# Passenger 18 leaves Airport Security at 2.94.
# Passenger 17's ID/Boarding Pass has been checked and verified.
# Passenger 28 arrives at the Airport Security at 3.00.
# Passenger 24's ID/Boarding Pass has been checked and verified.
# Passenger 17 enters Personal Scanner at 3.00.
# Passenger 29 arrives at the Airport Security at 3.00.
# Passenger 28 enters ID Check Station at 3.00.
# Passenger 24 enters Personal Scanner at 3.00.
# Passenger 30 arrives at the Airport Security at 3.00.
# Passenger 29 enters ID Check Station at 3.00.
# Passenger 28's ID/Boarding Pass has been checked and verified.
# Passenger 31 arrives at the Airport Security at 3.00.
# Passenger 30 enters ID Check Station at 3.00.
# Passenger 28 enters Personal Scanner at 3.00.
# Passenger 32 arrives at the Airport Security at 3.00.
# Passenger 31 enters ID Check Station at 3.00.
# Passenger 31's ID/Boarding Pass has been checked and verified.
# Passenger 31 enters Personal Scanner at 3.00.
# Passenger 32 enters ID Check Station at 3.00.
# Passenger 31 completes personal scanning process.
# Passenger 31 leaves Airport Security at 3.67.
# Passenger 17 completes personal scanning process.
# Passenger 17 leaves Airport Security at 3.70.
# Passenger 24 completes personal scanning process.
# Passenger 24 leaves Airport Security at 3.81.
# Passenger 28 completes personal scanning process.
# Passenger 28 leaves Airport Security at 3.96.
# Passenger 22's ID/Boarding Pass has been checked and verified.
# Passenger 29's ID/Boarding Pass has been checked and verified.
# Passenger 30's ID/Boarding Pass has been checked and verified.
# Passenger 33 arrives at the Airport Security at 4.00.
# Passenger 22 enters Personal Scanner at 4.00.
# Passenger 29 enters Personal Scanner at 4.00.
# Passenger 30 enters Personal Scanner at 4.00.
# Passenger 34 arrives at the Airport Security at 4.00.
# Passenger 35 arrives at the Airport Security at 4.00.
# Passenger 33 enters ID Check Station at 4.00.
# Passenger 34 enters ID Check Station at 4.00.
# Passenger 36 arrives at the Airport Security at 4.00.
# Passenger 35 enters ID Check Station at 4.00.
# Passenger 33's ID/Boarding Pass has been checked and verified.
# Passenger 34's ID/Boarding Pass has been checked and verified.
# Passenger 33 enters Personal Scanner at 4.00.
# Passenger 34 enters Personal Scanner at 4.00.
# Passenger 36 enters ID Check Station at 4.00.
# Passenger 36's ID/Boarding Pass has been checked and verified.
# Passenger 36 enters Personal Scanner at 4.00.
# Passenger 33 completes personal scanning process.
# Passenger 33 leaves Airport Security at 4.57.
# Passenger 36 completes personal scanning process.
# Passenger 36 leaves Airport Security at 4.60.
# Passenger 29 completes personal scanning process.
# Passenger 29 leaves Airport Security at 4.61.
# Passenger 34 completes personal scanning process.
# Passenger 34 leaves Airport Security at 4.71.
# Passenger 22 completes personal scanning process.
# Passenger 22 leaves Airport Security at 4.81.
# Passenger 30 completes personal scanning process.
# Passenger 30 leaves Airport Security at 4.97.
# Passenger 32's ID/Boarding Pass has been checked and verified.
# Passenger 37 arrives at the Airport Security at 5.00.
# Passenger 35's ID/Boarding Pass has been checked and verified.
# Passenger 32 enters Personal Scanner at 5.00.
# Passenger 38 arrives at the Airport Security at 5.00.
# Passenger 37 enters ID Check Station at 5.00.
# Passenger 35 enters Personal Scanner at 5.00.
# Passenger 39 arrives at the Airport Security at 5.00.
# Passenger 38 enters ID Check Station at 5.00.
# Passenger 40 arrives at the Airport Security at 5.00.
# Passenger 39 enters ID Check Station at 5.00.
# Passenger 38's ID/Boarding Pass has been checked and verified.
# Passenger 41 arrives at the Airport Security at 5.00.
# Passenger 40 enters ID Check Station at 5.00.
# Passenger 38 enters Personal Scanner at 5.00.
# Passenger 42 arrives at the Airport Security at 5.00.
# Passenger 40's ID/Boarding Pass has been checked and verified.
# Passenger 43 arrives at the Airport Security at 5.00.
# Passenger 41 enters ID Check Station at 5.00.
# Passenger 40 enters Personal Scanner at 5.00.
# Passenger 44 arrives at the Airport Security at 5.00.
# Passenger 41's ID/Boarding Pass has been checked and verified.
# Passenger 42 enters ID Check Station at 5.00.
# Passenger 41 enters Personal Scanner at 5.00.
# Passenger 43 enters ID Check Station at 5.00.
# Passenger 32 completes personal scanning process.
# Passenger 32 leaves Airport Security at 5.65.
# Passenger 41 completes personal scanning process.
# Passenger 41 leaves Airport Security at 5.93.
# Passenger 35 completes personal scanning process.
# Passenger 35 leaves Airport Security at 5.96.
# Passenger 38 completes personal scanning process.
# Passenger 38 leaves Airport Security at 5.99.
# Passenger 40 completes personal scanning process.
# Passenger 40 leaves Airport Security at 5.99.
# Passenger 39's ID/Boarding Pass has been checked and verified.
# Passenger 45 arrives at the Airport Security at 6.00.
# Passenger 42's ID/Boarding Pass has been checked and verified.
# Passenger 43's ID/Boarding Pass has been checked and verified.
# Passenger 39 enters Personal Scanner at 6.00.
# Passenger 46 arrives at the Airport Security at 6.00.
# Passenger 42 enters Personal Scanner at 6.00.
# Passenger 43 enters Personal Scanner at 6.00.
# Passenger 47 arrives at the Airport Security at 6.00.
# Passenger 44 enters ID Check Station at 6.00.
# Passenger 45 enters ID Check Station at 6.00.
# Passenger 48 arrives at the Airport Security at 6.00.
# Passenger 46 enters ID Check Station at 6.00.
# Passenger 49 arrives at the Airport Security at 6.00.
# Passenger 46's ID/Boarding Pass has been checked and verified.
# Passenger 50 arrives at the Airport Security at 6.00.
# Passenger 46 enters Personal Scanner at 6.00.
# Passenger 51 arrives at the Airport Security at 6.00.
# Passenger 52 arrives at the Airport Security at 6.00.
# Passenger 47 enters ID Check Station at 6.00.
# Passenger 53 arrives at the Airport Security at 6.00.
# Passenger 47's ID/Boarding Pass has been checked and verified.
# Passenger 54 arrives at the Airport Security at 6.00.
# Passenger 47 enters Personal Scanner at 6.00.
# Passenger 55 arrives at the Airport Security at 6.00.
# Passenger 56 arrives at the Airport Security at 6.00.
# Passenger 48 enters ID Check Station at 6.00.
# Passenger 39 completes personal scanning process.
# Passenger 39 leaves Airport Security at 6.60.
# Passenger 43 completes personal scanning process.
# Passenger 43 leaves Airport Security at 6.82.
# Passenger 47 completes personal scanning process.
# Passenger 47 leaves Airport Security at 6.85.
# Passenger 46 completes personal scanning process.
# Passenger 46 leaves Airport Security at 6.88.
# Passenger 42 completes personal scanning process.
# Passenger 42 leaves Airport Security at 6.90.
# Passenger 44's ID/Boarding Pass has been checked and verified.
# Passenger 45's ID/Boarding Pass has been checked and verified.
# Passenger 57 arrives at the Airport Security at 7.00.
# Passenger 48's ID/Boarding Pass has been checked and verified.
# Passenger 44 enters Personal Scanner at 7.00.
# Passenger 45 enters Personal Scanner at 7.00.
# Passenger 58 arrives at the Airport Security at 7.00.
# Passenger 48 enters Personal Scanner at 7.00.
# Passenger 59 arrives at the Airport Security at 7.00.
# Passenger 49 enters ID Check Station at 7.00.
# Passenger 50 enters ID Check Station at 7.00.
# Passenger 51 enters ID Check Station at 7.00.
# Passenger 60 arrives at the Airport Security at 7.00.
# Passenger 49's ID/Boarding Pass has been checked and verified.
# Passenger 50's ID/Boarding Pass has been checked and verified.
# Passenger 49 enters Personal Scanner at 7.00.
# Passenger 50 enters Personal Scanner at 7.00.
# Passenger 52 enters ID Check Station at 7.00.
# Passenger 53 enters ID Check Station at 7.00.
# Passenger 52's ID/Boarding Pass has been checked and verified.
# Passenger 52 enters Personal Scanner at 7.00.
# Passenger 54 enters ID Check Station at 7.00.
# Passenger 50 completes personal scanning process.
# Passenger 50 leaves Airport Security at 7.59.
# Passenger 45 completes personal scanning process.
# Passenger 45 leaves Airport Security at 7.59.
# Passenger 52 completes personal scanning process.
# Passenger 52 leaves Airport Security at 7.64.
# Passenger 49 completes personal scanning process.
# Passenger 49 leaves Airport Security at 7.65.
# Passenger 44 completes personal scanning process.
# Passenger 44 leaves Airport Security at 7.66.
# Passenger 48 completes personal scanning process.
# Passenger 48 leaves Airport Security at 7.96.
# Passenger 51's ID/Boarding Pass has been checked and verified.
# Passenger 61 arrives at the Airport Security at 8.00.
# Passenger 53's ID/Boarding Pass has been checked and verified.
# Passenger 54's ID/Boarding Pass has been checked and verified.
# Passenger 51 enters Personal Scanner at 8.00.
# Passenger 62 arrives at the Airport Security at 8.00.
# Passenger 53 enters Personal Scanner at 8.00.
# Passenger 54 enters Personal Scanner at 8.00.
# Passenger 63 arrives at the Airport Security at 8.00.
# Passenger 55 enters ID Check Station at 8.00.
# Passenger 56 enters ID Check Station at 8.00.
# Passenger 64 arrives at the Airport Security at 8.00.
# Passenger 57 enters ID Check Station at 8.00.
# Passenger 65 arrives at the Airport Security at 8.00.
# Passenger 66 arrives at the Airport Security at 8.00.
# Passenger 67 arrives at the Airport Security at 8.00.
# Passenger 68 arrives at the Airport Security at 8.00.
# Passenger 69 arrives at the Airport Security at 8.00.
# Passenger 70 arrives at the Airport Security at 8.00.
# Passenger 71 arrives at the Airport Security at 8.00.
# Passenger 72 arrives at the Airport Security at 8.00.
# Passenger 73 arrives at the Airport Security at 8.00.
# Passenger 74 arrives at the Airport Security at 8.00.
# Passenger 75 arrives at the Airport Security at 8.00.
# Passenger 76 arrives at the Airport Security at 8.00.
# Passenger 77 arrives at the Airport Security at 8.00.
# Passenger 78 arrives at the Airport Security at 8.00.
# Passenger 79 arrives at the Airport Security at 8.00.
# Passenger 80 arrives at the Airport Security at 8.00.
# Passenger 81 arrives at the Airport Security at 8.00.
# Passenger 54 completes personal scanning process.
# Passenger 54 leaves Airport Security at 8.87.
# Passenger 51 completes personal scanning process.
# Passenger 51 leaves Airport Security at 8.90.
# Passenger 53 completes personal scanning process.
# Passenger 53 leaves Airport Security at 8.99.
# Passenger 37's ID/Boarding Pass has been checked and verified.
# Passenger 57's ID/Boarding Pass has been checked and verified.
# Passenger 82 arrives at the Airport Security at 9.00.
# Passenger 37 enters Personal Scanner at 9.00.
# Passenger 57 enters Personal Scanner at 9.00.
# Passenger 83 arrives at the Airport Security at 9.00.
# Passenger 84 arrives at the Airport Security at 9.00.
# Passenger 58 enters ID Check Station at 9.00.
# Passenger 59 enters ID Check Station at 9.00.
# Passenger 85 arrives at the Airport Security at 9.00.
# Passenger 58's ID/Boarding Pass has been checked and verified.
# Passenger 58 enters Personal Scanner at 9.00.
# Passenger 60 enters ID Check Station at 9.00.
# Passenger 57 completes personal scanning process.
# Passenger 57 leaves Airport Security at 9.57.
# Passenger 58 completes personal scanning process.
# Passenger 58 leaves Airport Security at 9.77.
# Passenger 37 completes personal scanning process.
# Passenger 37 leaves Airport Security at 9.90.
# Passenger 86 arrives at the Airport Security at 10.00.
# Passenger 60's ID/Boarding Pass has been checked and verified.
# Passenger 87 arrives at the Airport Security at 10.00.
# Passenger 60 enters Personal Scanner at 10.00.
# Passenger 88 arrives at the Airport Security at 10.00.
# Passenger 89 arrives at the Airport Security at 10.00.
# Passenger 61 enters ID Check Station at 10.00.
# Passenger 90 arrives at the Airport Security at 10.00.
# Passenger 60 completes personal scanning process.
# Passenger 60 leaves Airport Security at 10.76.
# Passenger 56's ID/Boarding Pass has been checked and verified.
# Passenger 59's ID/Boarding Pass has been checked and verified.
# Passenger 61's ID/Boarding Pass has been checked and verified.
# Passenger 91 arrives at the Airport Security at 11.00.
# Passenger 56 enters Personal Scanner at 11.00.
# Passenger 59 enters Personal Scanner at 11.00.
# Passenger 61 enters Personal Scanner at 11.00.
# Passenger 92 arrives at the Airport Security at 11.00.
# Passenger 93 arrives at the Airport Security at 11.00.
# Passenger 62 enters ID Check Station at 11.00.
# Passenger 63 enters ID Check Station at 11.00.
# Passenger 64 enters ID Check Station at 11.00.
# Passenger 94 arrives at the Airport Security at 11.00.
# Passenger 64's ID/Boarding Pass has been checked and verified.
# Passenger 95 arrives at the Airport Security at 11.00.
# Passenger 64 enters Personal Scanner at 11.00.
# Passenger 96 arrives at the Airport Security at 11.00.
# Passenger 97 arrives at the Airport Security at 11.00.
# Passenger 65 enters ID Check Station at 11.00.
# Passenger 98 arrives at the Airport Security at 11.00.
# Passenger 65's ID/Boarding Pass has been checked and verified.
# Passenger 99 arrives at the Airport Security at 11.00.
# Passenger 65 enters Personal Scanner at 11.00.
# Passenger 100 arrives at the Airport Security at 11.00.
# Passenger 101 arrives at the Airport Security at 11.00.
# Passenger 66 enters ID Check Station at 11.00.
# Passenger 102 arrives at the Airport Security at 11.00.
# Passenger 103 arrives at the Airport Security at 11.00.
# Passenger 65 completes personal scanning process.
# Passenger 65 leaves Airport Security at 11.57.
# Passenger 56 completes personal scanning process.
# Passenger 56 leaves Airport Security at 11.69.
# Passenger 64 completes personal scanning process.
# Passenger 64 leaves Airport Security at 11.72.
# Passenger 59 completes personal scanning process.
# Passenger 59 leaves Airport Security at 11.90.
# Passenger 61 completes personal scanning process.
# Passenger 61 leaves Airport Security at 11.99.
# Passenger 55's ID/Boarding Pass has been checked and verified.
# Passenger 62's ID/Boarding Pass has been checked and verified.
# Passenger 63's ID/Boarding Pass has been checked and verified.
# Passenger 66's ID/Boarding Pass has been checked and verified.
# Passenger 104 arrives at the Airport Security at 12.00.
# Passenger 55 enters Personal Scanner at 12.00.
# Passenger 62 enters Personal Scanner at 12.00.
# Passenger 63 enters Personal Scanner at 12.00.
# Passenger 66 enters Personal Scanner at 12.00.
# Passenger 105 arrives at the Airport Security at 12.00.
# Passenger 106 arrives at the Airport Security at 12.00.
# Passenger 67 enters ID Check Station at 12.00.
# Passenger 68 enters ID Check Station at 12.00.
# Passenger 69 enters ID Check Station at 12.00.
# Passenger 70 enters ID Check Station at 12.00.
# Passenger 107 arrives at the Airport Security at 12.00.
# Passenger 67's ID/Boarding Pass has been checked and verified.
# Passenger 70's ID/Boarding Pass has been checked and verified.
# Passenger 108 arrives at the Airport Security at 12.00.
# Passenger 67 enters Personal Scanner at 12.00.
# Passenger 70 enters Personal Scanner at 12.00.
# Passenger 109 arrives at the Airport Security at 12.00.
# Passenger 110 arrives at the Airport Security at 12.00.
# Passenger 71 enters ID Check Station at 12.00.
# Passenger 72 enters ID Check Station at 12.00.
# Passenger 72's ID/Boarding Pass has been checked and verified.
# Passenger 72 enters Personal Scanner at 12.00.
# Passenger 73 enters ID Check Station at 12.00.
# Passenger 70 completes personal scanning process.
# Passenger 70 leaves Airport Security at 12.62.
# Passenger 67 completes personal scanning process.
# Passenger 67 leaves Airport Security at 12.62.
# Passenger 66 completes personal scanning process.
# Passenger 66 leaves Airport Security at 12.65.
# Passenger 63 completes personal scanning process.
# Passenger 63 leaves Airport Security at 12.73.
# Passenger 72 completes personal scanning process.
# Passenger 72 leaves Airport Security at 12.77.
# Passenger 55 completes personal scanning process.
# Passenger 55 leaves Airport Security at 12.81.
# Passenger 62 completes personal scanning process.
# Passenger 62 leaves Airport Security at 12.96.
# Passenger 68's ID/Boarding Pass has been checked and verified.
# Passenger 111 arrives at the Airport Security at 13.00.
# Passenger 71's ID/Boarding Pass has been checked and verified.
# Passenger 73's ID/Boarding Pass has been checked and verified.
# Passenger 68 enters Personal Scanner at 13.00.
# Passenger 112 arrives at the Airport Security at 13.00.
# Passenger 71 enters Personal Scanner at 13.00.
# Passenger 73 enters Personal Scanner at 13.00.
# Passenger 113 arrives at the Airport Security at 13.00.
# Passenger 74 enters ID Check Station at 13.00.
# Passenger 75 enters ID Check Station at 13.00.
# Passenger 76 enters ID Check Station at 13.00.
# Passenger 74's ID/Boarding Pass has been checked and verified.
# Passenger 75's ID/Boarding Pass has been checked and verified.
# Passenger 76's ID/Boarding Pass has been checked and verified.
# Passenger 74 enters Personal Scanner at 13.00.
# Passenger 75 enters Personal Scanner at 13.00.
# Passenger 76 enters Personal Scanner at 13.00.
# Passenger 77 enters ID Check Station at 13.00.
# Passenger 78 enters ID Check Station at 13.00.
# Passenger 79 enters ID Check Station at 13.00.
# Passenger 71 completes personal scanning process.
# Passenger 71 leaves Airport Security at 13.53.
# Passenger 75 completes personal scanning process.
# Passenger 75 leaves Airport Security at 13.64.
# Passenger 68 completes personal scanning process.
# Passenger 68 leaves Airport Security at 13.66.
# Passenger 73 completes personal scanning process.
# Passenger 73 leaves Airport Security at 13.84.
# Passenger 76 completes personal scanning process.
# Passenger 76 leaves Airport Security at 13.92.
# Passenger 74 completes personal scanning process.
# Passenger 74 leaves Airport Security at 13.97.
# Passenger 69's ID/Boarding Pass has been checked and verified.
# Passenger 77's ID/Boarding Pass has been checked and verified.
# Passenger 78's ID/Boarding Pass has been checked and verified.
# Passenger 79's ID/Boarding Pass has been checked and verified.
# Passenger 69 enters Personal Scanner at 14.00.
# Passenger 77 enters Personal Scanner at 14.00.
# Passenger 78 enters Personal Scanner at 14.00.
# Passenger 79 enters Personal Scanner at 14.00.
# Passenger 80 enters ID Check Station at 14.00.
# Passenger 81 enters ID Check Station at 14.00.
# Passenger 82 enters ID Check Station at 14.00.
# Passenger 83 enters ID Check Station at 14.00.
# Passenger 83's ID/Boarding Pass has been checked and verified.
# Passenger 83 enters Personal Scanner at 14.00.
# Passenger 84 enters ID Check Station at 14.00.
# Passenger 77 completes personal scanning process.
# Passenger 77 leaves Airport Security at 14.50.
# Passenger 79 completes personal scanning process.
# Passenger 79 leaves Airport Security at 14.50.
# Passenger 78 completes personal scanning process.
# Passenger 78 leaves Airport Security at 14.69.
# Passenger 83 completes personal scanning process.
# Passenger 83 leaves Airport Security at 14.73.
# Passenger 69 completes personal scanning process.
# Passenger 69 leaves Airport Security at 14.85.
# Passenger 114 arrives at the Airport Security at 15.00.
# Passenger 80's ID/Boarding Pass has been checked and verified.
# Passenger 81's ID/Boarding Pass has been checked and verified.
# Passenger 84's ID/Boarding Pass has been checked and verified.
# Passenger 115 arrives at the Airport Security at 15.00.
# Passenger 80 enters Personal Scanner at 15.00.
# Passenger 81 enters Personal Scanner at 15.00.
# Passenger 84 enters Personal Scanner at 15.00.
# Passenger 116 arrives at the Airport Security at 15.00.
# Passenger 117 arrives at the Airport Security at 15.00.
# Passenger 85 enters ID Check Station at 15.00.
# Passenger 86 enters ID Check Station at 15.00.
# Passenger 87 enters ID Check Station at 15.00.
# Passenger 118 arrives at the Airport Security at 15.00.
# Passenger 87's ID/Boarding Pass has been checked and verified.
# Passenger 87 enters Personal Scanner at 15.00.
# Passenger 88 enters ID Check Station at 15.00.
# Passenger 88's ID/Boarding Pass has been checked and verified.
# Passenger 88 enters Personal Scanner at 15.00.
# Passenger 89 enters ID Check Station at 15.00.
# Passenger 89's ID/Boarding Pass has been checked and verified.
# Passenger 89 enters Personal Scanner at 15.00.
# Passenger 90 enters ID Check Station at 15.00.
# Passenger 80 completes personal scanning process.
# Passenger 80 leaves Airport Security at 15.50.
# Passenger 87 completes personal scanning process.
# Passenger 87 leaves Airport Security at 15.57.
# Passenger 88 completes personal scanning process.
# Passenger 88 leaves Airport Security at 15.68.
# Passenger 84 completes personal scanning process.
# Passenger 84 leaves Airport Security at 15.72.
# Passenger 81 completes personal scanning process.
# Passenger 81 leaves Airport Security at 15.88.
# Passenger 89 completes personal scanning process.
# Passenger 89 leaves Airport Security at 15.92.
# Passenger 85's ID/Boarding Pass has been checked and verified.
# Passenger 119 arrives at the Airport Security at 16.00.
# Passenger 90's ID/Boarding Pass has been checked and verified.
# Passenger 85 enters Personal Scanner at 16.00.
# Passenger 120 arrives at the Airport Security at 16.00.
# Passenger 90 enters Personal Scanner at 16.00.
# Passenger 91 enters ID Check Station at 16.00.
# Passenger 92 enters ID Check Station at 16.00.
# Passenger 85 completes personal scanning process.
# Passenger 85 leaves Airport Security at 16.60.
# Passenger 90 completes personal scanning process.
# Passenger 90 leaves Airport Security at 16.82.
# Passenger 82's ID/Boarding Pass has been checked and verified.
# Passenger 121 arrives at the Airport Security at 17.00.
# Passenger 91's ID/Boarding Pass has been checked and verified.
# Passenger 82 enters Personal Scanner at 17.00.
# Passenger 122 arrives at the Airport Security at 17.00.
# Passenger 91 enters Personal Scanner at 17.00.
# Passenger 123 arrives at the Airport Security at 17.00.
# Passenger 93 enters ID Check Station at 17.00.
# Passenger 94 enters ID Check Station at 17.00.
# Passenger 93's ID/Boarding Pass has been checked and verified.
# Passenger 93 enters Personal Scanner at 17.00.
# Passenger 95 enters ID Check Station at 17.00.
# Passenger 91 completes personal scanning process.
# Passenger 91 leaves Airport Security at 17.67.
# Passenger 93 completes personal scanning process.
# Passenger 93 leaves Airport Security at 17.69.
# Passenger 82 completes personal scanning process.
# Passenger 82 leaves Airport Security at 17.93.
# Passenger 124 arrives at the Airport Security at 18.00.
# Passenger 94's ID/Boarding Pass has been checked and verified.
# Passenger 95's ID/Boarding Pass has been checked and verified.
# Passenger 125 arrives at the Airport Security at 18.00.
# Passenger 94 enters Personal Scanner at 18.00.
# Passenger 95 enters Personal Scanner at 18.00.
# Passenger 126 arrives at the Airport Security at 18.00.
# Passenger 127 arrives at the Airport Security at 18.00.
# Passenger 96 enters ID Check Station at 18.00.
# Passenger 97 enters ID Check Station at 18.00.
# Passenger 128 arrives at the Airport Security at 18.00.
# Passenger 129 arrives at the Airport Security at 18.00.
# Passenger 130 arrives at the Airport Security at 18.00.
# Passenger 131 arrives at the Airport Security at 18.00.
# Passenger 132 arrives at the Airport Security at 18.00.
# Passenger 133 arrives at the Airport Security at 18.00.
# Passenger 134 arrives at the Airport Security at 18.00.
# Passenger 135 arrives at the Airport Security at 18.00.
# Passenger 94 completes personal scanning process.
# Passenger 94 leaves Airport Security at 18.51.
# Passenger 95 completes personal scanning process.
# Passenger 95 leaves Airport Security at 18.76.
# Passenger 86's ID/Boarding Pass has been checked and verified.
# Passenger 92's ID/Boarding Pass has been checked and verified.
# Passenger 96's ID/Boarding Pass has been checked and verified.
# Passenger 97's ID/Boarding Pass has been checked and verified.
# Passenger 136 arrives at the Airport Security at 19.00.
# Passenger 86 enters Personal Scanner at 19.00.
# Passenger 92 enters Personal Scanner at 19.00.
# Passenger 96 enters Personal Scanner at 19.00.
# Passenger 97 enters Personal Scanner at 19.00.
# Passenger 137 arrives at the Airport Security at 19.00.
# Passenger 138 arrives at the Airport Security at 19.00.
# Passenger 98 enters ID Check Station at 19.00.
# Passenger 99 enters ID Check Station at 19.00.
# Passenger 100 enters ID Check Station at 19.00.
# Passenger 101 enters ID Check Station at 19.00.
# Passenger 139 arrives at the Airport Security at 19.00.
# Passenger 98's ID/Boarding Pass has been checked and verified.
# Passenger 100's ID/Boarding Pass has been checked and verified.
# Passenger 101's ID/Boarding Pass has been checked and verified.
# Passenger 140 arrives at the Airport Security at 19.00.
# Passenger 98 enters Personal Scanner at 19.00.
# Passenger 100 enters Personal Scanner at 19.00.
# Passenger 101 enters Personal Scanner at 19.00.
# Passenger 102 enters ID Check Station at 19.00.
# Passenger 103 enters ID Check Station at 19.00.
# Passenger 104 enters ID Check Station at 19.00.
# Passenger 103's ID/Boarding Pass has been checked and verified.
# Passenger 104's ID/Boarding Pass has been checked and verified.
# Passenger 103 enters Personal Scanner at 19.00.
# Passenger 104 enters Personal Scanner at 19.00.
# Passenger 105 enters ID Check Station at 19.00.
# Passenger 106 enters ID Check Station at 19.00.
# Passenger 106's ID/Boarding Pass has been checked and verified.
# Passenger 106 enters Personal Scanner at 19.00.
# Passenger 107 enters ID Check Station at 19.00.
# Passenger 101 completes personal scanning process.
# Passenger 101 leaves Airport Security at 19.58.
# Passenger 96 completes personal scanning process.
# Passenger 96 leaves Airport Security at 19.62.
# Passenger 106 completes personal scanning process.
# Passenger 106 leaves Airport Security at 19.65.
# Passenger 104 completes personal scanning process.
# Passenger 104 leaves Airport Security at 19.87.
# Passenger 100 completes personal scanning process.
# Passenger 100 leaves Airport Security at 19.89.
# Passenger 86 completes personal scanning process.
# Passenger 86 leaves Airport Security at 19.90.
# Passenger 97 completes personal scanning process.
# Passenger 97 leaves Airport Security at 19.92.
# Passenger 92 completes personal scanning process.
# Passenger 92 leaves Airport Security at 19.96.
# Passenger 98 completes personal scanning process.
# Passenger 98 leaves Airport Security at 19.99.
# Passenger 103 completes personal scanning process.
# Passenger 103 leaves Airport Security at 19.99.
# Passenger 99's ID/Boarding Pass has been checked and verified.
# Passenger 105's ID/Boarding Pass has been checked and verified.
# Passenger 107's ID/Boarding Pass has been checked and verified.
# Passenger 99 enters Personal Scanner at 20.00.
# Passenger 105 enters Personal Scanner at 20.00.
# Passenger 107 enters Personal Scanner at 20.00.
# Passenger 108 enters ID Check Station at 20.00.
# Passenger 109 enters ID Check Station at 20.00.
# Passenger 110 enters ID Check Station at 20.00.
# Passenger 109's ID/Boarding Pass has been checked and verified.
# Passenger 109 enters Personal Scanner at 20.00.
# Passenger 111 enters ID Check Station at 20.00.
# Passenger 111's ID/Boarding Pass has been checked and verified.
# Passenger 111 enters Personal Scanner at 20.00.
# Passenger 112 enters ID Check Station at 20.00.
# Passenger 105 completes personal scanning process.
# Passenger 105 leaves Airport Security at 20.76.
# Passenger 109 completes personal scanning process.
# Passenger 109 leaves Airport Security at 20.82.
# Passenger 107 completes personal scanning process.
# Passenger 107 leaves Airport Security at 20.86.
# Passenger 111 completes personal scanning process.
# Passenger 111 leaves Airport Security at 20.87.
# Passenger 99 completes personal scanning process.
# Passenger 99 leaves Airport Security at 20.91.
# Passenger 141 arrives at the Airport Security at 21.00.
# Passenger 102's ID/Boarding Pass has been checked and verified.
# Passenger 108's ID/Boarding Pass has been checked and verified.
# Passenger 110's ID/Boarding Pass has been checked and verified.
# Passenger 112's ID/Boarding Pass has been checked and verified.
# Passenger 142 arrives at the Airport Security at 21.00.
# Passenger 102 enters Personal Scanner at 21.00.
# Passenger 108 enters Personal Scanner at 21.00.
# Passenger 110 enters Personal Scanner at 21.00.
# Passenger 112 enters Personal Scanner at 21.00.
# Passenger 143 arrives at the Airport Security at 21.00.
# Passenger 113 enters ID Check Station at 21.00.
# Passenger 114 enters ID Check Station at 21.00.
# Passenger 115 enters ID Check Station at 21.00.
# Passenger 116 enters ID Check Station at 21.00.
# Passenger 102 completes personal scanning process.
# Passenger 102 leaves Airport Security at 21.57.
# Passenger 110 completes personal scanning process.
# Passenger 110 leaves Airport Security at 21.64.
# Passenger 112 completes personal scanning process.
# Passenger 112 leaves Airport Security at 21.74.
# Passenger 108 completes personal scanning process.
# Passenger 108 leaves Airport Security at 21.79.
# Passenger 144 arrives at the Airport Security at 22.00.
# Passenger 113's ID/Boarding Pass has been checked and verified.
# Passenger 116's ID/Boarding Pass has been checked and verified.
# Passenger 145 arrives at the Airport Security at 22.00.
# Passenger 113 enters Personal Scanner at 22.00.
# Passenger 116 enters Personal Scanner at 22.00.
# Passenger 146 arrives at the Airport Security at 22.00.
# Passenger 117 enters ID Check Station at 22.00.
# Passenger 118 enters ID Check Station at 22.00.
# Passenger 118's ID/Boarding Pass has been checked and verified.
# Passenger 118 enters Personal Scanner at 22.00.
# Passenger 119 enters ID Check Station at 22.00.
# Passenger 116 completes personal scanning process.
# Passenger 116 leaves Airport Security at 22.68.
# Passenger 118 completes personal scanning process.
# Passenger 118 leaves Airport Security at 22.82.
# Passenger 113 completes personal scanning process.
# Passenger 113 leaves Airport Security at 22.85.
# Passenger 114's ID/Boarding Pass has been checked and verified.
# Passenger 147 arrives at the Airport Security at 23.00.
# Passenger 117's ID/Boarding Pass has been checked and verified.
# Passenger 119's ID/Boarding Pass has been checked and verified.
# Passenger 114 enters Personal Scanner at 23.00.
# Passenger 148 arrives at the Airport Security at 23.00.
# Passenger 117 enters Personal Scanner at 23.00.
# Passenger 119 enters Personal Scanner at 23.00.
# Passenger 149 arrives at the Airport Security at 23.00.
# Passenger 120 enters ID Check Station at 23.00.
# Passenger 121 enters ID Check Station at 23.00.
# Passenger 150 arrives at the Airport Security at 23.00.
# Passenger 122 enters ID Check Station at 23.00.
# Passenger 120's ID/Boarding Pass has been checked and verified.
# Passenger 121's ID/Boarding Pass has been checked and verified.
# Passenger 151 arrives at the Airport Security at 23.00.
# Passenger 122's ID/Boarding Pass has been checked and verified.
# Passenger 120 enters Personal Scanner at 23.00.
# Passenger 121 enters Personal Scanner at 23.00.
# Passenger 152 arrives at the Airport Security at 23.00.
# Passenger 122 enters Personal Scanner at 23.00.
# Passenger 123 enters ID Check Station at 23.00.
# Passenger 124 enters ID Check Station at 23.00.
# Passenger 125 enters ID Check Station at 23.00.
# Passenger 123's ID/Boarding Pass has been checked and verified.
# Passenger 124's ID/Boarding Pass has been checked and verified.
# Passenger 123 enters Personal Scanner at 23.00.
# Passenger 124 enters Personal Scanner at 23.00.
# Passenger 126 enters ID Check Station at 23.00.
# Passenger 127 enters ID Check Station at 23.00.
# Passenger 126's ID/Boarding Pass has been checked and verified.
# Passenger 127's ID/Boarding Pass has been checked and verified.
# Passenger 126 enters Personal Scanner at 23.00.
# Passenger 127 enters Personal Scanner at 23.00.
# Passenger 128 enters ID Check Station at 23.00.
# Passenger 129 enters ID Check Station at 23.00.
# Passenger 126 completes personal scanning process.
# Passenger 126 leaves Airport Security at 23.68.
# Passenger 119 completes personal scanning process.
# Passenger 119 leaves Airport Security at 23.68.
# Passenger 122 completes personal scanning process.
# Passenger 122 leaves Airport Security at 23.69.
# Passenger 114 completes personal scanning process.
# Passenger 114 leaves Airport Security at 23.69.
# Passenger 121 completes personal scanning process.
# Passenger 121 leaves Airport Security at 23.72.
# Passenger 127 completes personal scanning process.
# Passenger 127 leaves Airport Security at 23.75.
# Passenger 117 completes personal scanning process.
# Passenger 117 leaves Airport Security at 23.77.
# Passenger 123 completes personal scanning process.
# Passenger 123 leaves Airport Security at 23.93.
# Passenger 124 completes personal scanning process.
# Passenger 124 leaves Airport Security at 23.97.
# Passenger 120 completes personal scanning process.
# Passenger 120 leaves Airport Security at 23.99.
# Passenger 115's ID/Boarding Pass has been checked and verified.
# Passenger 153 arrives at the Airport Security at 24.00.
# Passenger 125's ID/Boarding Pass has been checked and verified.
# Passenger 128's ID/Boarding Pass has been checked and verified.
# Passenger 115 enters Personal Scanner at 24.00.
# Passenger 154 arrives at the Airport Security at 24.00.
# Passenger 125 enters Personal Scanner at 24.00.
# Passenger 128 enters Personal Scanner at 24.00.
# Passenger 130 enters ID Check Station at 24.00.
# Passenger 131 enters ID Check Station at 24.00.
# Passenger 132 enters ID Check Station at 24.00.
# Passenger 132's ID/Boarding Pass has been checked and verified.
# Passenger 132 enters Personal Scanner at 24.00.
# Passenger 133 enters ID Check Station at 24.00.
# Passenger 128 completes personal scanning process.
# Passenger 128 leaves Airport Security at 24.54.
# Passenger 132 completes personal scanning process.
# Passenger 132 leaves Airport Security at 24.85.
# Passenger 125 completes personal scanning process.
# Passenger 125 leaves Airport Security at 24.88.
# Passenger 115 completes personal scanning process.
# Passenger 115 leaves Airport Security at 24.95.
# Passenger 129's ID/Boarding Pass has been checked and verified.
# Passenger 155 arrives at the Airport Security at 25.00.
# Passenger 130's ID/Boarding Pass has been checked and verified.
# Passenger 131's ID/Boarding Pass has been checked and verified.
# Passenger 133's ID/Boarding Pass has been checked and verified.
# Passenger 129 enters Personal Scanner at 25.00.
# Passenger 156 arrives at the Airport Security at 25.00.
# Passenger 130 enters Personal Scanner at 25.00.
# Passenger 131 enters Personal Scanner at 25.00.
# Passenger 133 enters Personal Scanner at 25.00.
# Passenger 157 arrives at the Airport Security at 25.00.
# Passenger 134 enters ID Check Station at 25.00.
# Passenger 135 enters ID Check Station at 25.00.
# Passenger 158 arrives at the Airport Security at 25.00.
# Passenger 136 enters ID Check Station at 25.00.
# Passenger 134's ID/Boarding Pass has been checked and verified.
# Passenger 137 enters ID Check Station at 25.00.
# Passenger 135's ID/Boarding Pass has been checked and verified.
# Passenger 159 arrives at the Airport Security at 25.00.
# Passenger 136's ID/Boarding Pass has been checked and verified.
# Passenger 134 enters Personal Scanner at 25.00.
# Passenger 135 enters Personal Scanner at 25.00.
# Passenger 160 arrives at the Airport Security at 25.00.
# Passenger 136 enters Personal Scanner at 25.00.
# Passenger 161 arrives at the Airport Security at 25.00.
# Passenger 138 enters ID Check Station at 25.00.
# Passenger 139 enters ID Check Station at 25.00.
# Passenger 140 enters ID Check Station at 25.00.
# Passenger 162 arrives at the Airport Security at 25.00.
# Passenger 139's ID/Boarding Pass has been checked and verified.
# Passenger 140's ID/Boarding Pass has been checked and verified.
# Passenger 163 arrives at the Airport Security at 25.00.
# Passenger 139 enters Personal Scanner at 25.00.
# Passenger 140 enters Personal Scanner at 25.00.
# Passenger 164 arrives at the Airport Security at 25.00.
# Passenger 165 arrives at the Airport Security at 25.00.
# Passenger 141 enters ID Check Station at 25.00.
# Passenger 142 enters ID Check Station at 25.00.
# Passenger 166 arrives at the Airport Security at 25.00.
# Passenger 142's ID/Boarding Pass has been checked and verified.
# Passenger 167 arrives at the Airport Security at 25.00.
# Passenger 142 enters Personal Scanner at 25.00.
# Passenger 168 arrives at the Airport Security at 25.00.
# Passenger 169 arrives at the Airport Security at 25.00.
# Passenger 143 enters ID Check Station at 25.00.
# Passenger 170 arrives at the Airport Security at 25.00.
# Passenger 143's ID/Boarding Pass has been checked and verified.
# Passenger 171 arrives at the Airport Security at 25.00.
# Passenger 143 enters Personal Scanner at 25.00.
# Passenger 172 arrives at the Airport Security at 25.00.
# Passenger 173 arrives at the Airport Security at 25.00.
# Passenger 144 enters ID Check Station at 25.00.
# Passenger 174 arrives at the Airport Security at 25.00.
# Passenger 144's ID/Boarding Pass has been checked and verified.
# Passenger 144 enters Personal Scanner at 25.00.
# Passenger 145 enters ID Check Station at 25.00.
# Passenger 145's ID/Boarding Pass has been checked and verified.
# Passenger 145 enters Personal Scanner at 25.00.
# Passenger 146 enters ID Check Station at 25.00.
# Passenger 146's ID/Boarding Pass has been checked and verified.
# Passenger 146 enters Personal Scanner at 25.00.
# Passenger 147 enters ID Check Station at 25.00.
# Passenger 129 completes personal scanning process.
# Passenger 129 leaves Airport Security at 25.52.
# Passenger 145 completes personal scanning process.
# Passenger 145 leaves Airport Security at 25.62.
# Passenger 142 completes personal scanning process.
# Passenger 142 leaves Airport Security at 25.64.
# Passenger 131 completes personal scanning process.
# Passenger 131 leaves Airport Security at 25.66.
# Passenger 146 completes personal scanning process.
# Passenger 146 leaves Airport Security at 25.71.
# Passenger 130 completes personal scanning process.
# Passenger 130 leaves Airport Security at 25.80.
# Passenger 134 completes personal scanning process.
# Passenger 134 leaves Airport Security at 25.80.
# Passenger 139 completes personal scanning process.
# Passenger 139 leaves Airport Security at 25.85.
# Passenger 133 completes personal scanning process.
# Passenger 133 leaves Airport Security at 25.86.
# Passenger 144 completes personal scanning process.
# Passenger 144 leaves Airport Security at 25.89.
# Passenger 140 completes personal scanning process.
# Passenger 140 leaves Airport Security at 25.90.
# Passenger 143 completes personal scanning process.
# Passenger 143 leaves Airport Security at 25.94.
# Passenger 135 completes personal scanning process.
# Passenger 135 leaves Airport Security at 25.94.
# Passenger 136 completes personal scanning process.
# Passenger 136 leaves Airport Security at 25.98.
# Passenger 138's ID/Boarding Pass has been checked and verified.
# Passenger 141's ID/Boarding Pass has been checked and verified.
# Passenger 175 arrives at the Airport Security at 26.00.
# Passenger 138 enters Personal Scanner at 26.00.
# Passenger 141 enters Personal Scanner at 26.00.
# Passenger 176 arrives at the Airport Security at 26.00.
# Passenger 177 arrives at the Airport Security at 26.00.
# Passenger 148 enters ID Check Station at 26.00.
# Passenger 149 enters ID Check Station at 26.00.
# Passenger 178 arrives at the Airport Security at 26.00.
# Passenger 149's ID/Boarding Pass has been checked and verified.
# Passenger 179 arrives at the Airport Security at 26.00.
# Passenger 149 enters Personal Scanner at 26.00.
# Passenger 180 arrives at the Airport Security at 26.00.
# Passenger 181 arrives at the Airport Security at 26.00.
# Passenger 150 enters ID Check Station at 26.00.
# Passenger 141 completes personal scanning process.
# Passenger 141 leaves Airport Security at 26.55.
# Passenger 149 completes personal scanning process.
# Passenger 149 leaves Airport Security at 26.82.
# Passenger 138 completes personal scanning process.
# Passenger 138 leaves Airport Security at 26.94.
# Passenger 147's ID/Boarding Pass has been checked and verified.
# Passenger 148's ID/Boarding Pass has been checked and verified.
# Passenger 182 arrives at the Airport Security at 27.00.
# Passenger 150's ID/Boarding Pass has been checked and verified.
# Passenger 147 enters Personal Scanner at 27.00.
# Passenger 148 enters Personal Scanner at 27.00.
# Passenger 183 arrives at the Airport Security at 27.00.
# Passenger 150 enters Personal Scanner at 27.00.
# Passenger 184 arrives at the Airport Security at 27.00.
# Passenger 151 enters ID Check Station at 27.00.
# Passenger 152 enters ID Check Station at 27.00.
# Passenger 153 enters ID Check Station at 27.00.
# Passenger 185 arrives at the Airport Security at 27.00.
# ...
# Passenger 1224 completes personal scanning process.
# Passenger 1224 leaves Airport Security at 228.60.
# Passenger 1241 completes personal scanning process.
# Passenger 1241 leaves Airport Security at 228.62.
# Passenger 1225 completes personal scanning process.
# Passenger 1225 leaves Airport Security at 228.69.
# Passenger 1237 completes personal scanning process.
# Passenger 1237 leaves Airport Security at 228.80.
# Passenger 1238 completes personal scanning process.
# Passenger 1238 leaves Airport Security at 229.00.
# Passenger 1239's ID/Boarding Pass has been checked and verified.
# Passenger 1253 arrives at the Airport Security at 229.00.
# Passenger 1240's ID/Boarding Pass has been checked and verified.
# Passenger 1242's ID/Boarding Pass has been checked and verified.
# Passenger 1239 enters Personal Scanner at 229.00.
# Passenger 1254 arrives at the Airport Security at 229.00.
# Passenger 1240 enters Personal Scanner at 229.00.
# Passenger 1242 enters Personal Scanner at 229.00.
# Passenger 1255 arrives at the Airport Security at 229.00.
# Passenger 1243 enters ID Check Station at 229.00.
# Passenger 1244 enters ID Check Station at 229.00.
# Passenger 1256 arrives at the Airport Security at 229.00.
# Passenger 1245 enters ID Check Station at 229.00.
# Passenger 1244's ID/Boarding Pass has been checked and verified.
# Passenger 1257 arrives at the Airport Security at 229.00.
# Passenger 1244 enters Personal Scanner at 229.00.
# Passenger 1246 enters ID Check Station at 229.00.
# Passenger 1239 completes personal scanning process.
# Passenger 1239 leaves Airport Security at 229.57.
# Passenger 1242 completes personal scanning process.
# Passenger 1242 leaves Airport Security at 229.61.
# Passenger 1244 completes personal scanning process.
# Passenger 1244 leaves Airport Security at 229.75.
# Passenger 1240 completes personal scanning process.
# Passenger 1240 leaves Airport Security at 229.90.
# Passenger 1236's ID/Boarding Pass has been checked and verified.
# Passenger 1243's ID/Boarding Pass has been checked and verified.
# Passenger 1245's ID/Boarding Pass has been checked and verified.
# Passenger 1258 arrives at the Airport Security at 230.00.
# Passenger 1246's ID/Boarding Pass has been checked and verified.
# Passenger 1236 enters Personal Scanner at 230.00.
# Passenger 1243 enters Personal Scanner at 230.00.
# Passenger 1245 enters Personal Scanner at 230.00.
# Passenger 1259 arrives at the Airport Security at 230.00.
# Passenger 1246 enters Personal Scanner at 230.00.
# Passenger 1260 arrives at the Airport Security at 230.00.
# Passenger 1247 enters ID Check Station at 230.00.
# Passenger 1248 enters ID Check Station at 230.00.
# Passenger 1249 enters ID Check Station at 230.00.
# Passenger 1250 enters ID Check Station at 230.00.
# Passenger 1261 arrives at the Airport Security at 230.00.
# Passenger 1247's ID/Boarding Pass has been checked and verified.
# Passenger 1248's ID/Boarding Pass has been checked and verified.
# Passenger 1250's ID/Boarding Pass has been checked and verified.
# Passenger 1262 arrives at the Airport Security at 230.00.
# Passenger 1247 enters Personal Scanner at 230.00.
# Passenger 1248 enters Personal Scanner at 230.00.
# Passenger 1250 enters Personal Scanner at 230.00.
# Passenger 1263 arrives at the Airport Security at 230.00.
# Passenger 1264 arrives at the Airport Security at 230.00.
# Passenger 1251 enters ID Check Station at 230.00.
# Passenger 1252 enters ID Check Station at 230.00.
# Passenger 1253 enters ID Check Station at 230.00.
# Passenger 1265 arrives at the Airport Security at 230.00.
# Passenger 1251's ID/Boarding Pass has been checked and verified.
# Passenger 1252's ID/Boarding Pass has been checked and verified.
# Passenger 1253's ID/Boarding Pass has been checked and verified.
# Passenger 1266 arrives at the Airport Security at 230.00.
# Passenger 1251 enters Personal Scanner at 230.00.
# Passenger 1252 enters Personal Scanner at 230.00.
# Passenger 1253 enters Personal Scanner at 230.00.
# Passenger 1267 arrives at the Airport Security at 230.00.
# Passenger 1268 arrives at the Airport Security at 230.00.
# Passenger 1254 enters ID Check Station at 230.00.
# Passenger 1255 enters ID Check Station at 230.00.
# Passenger 1256 enters ID Check Station at 230.00.
# Passenger 1254's ID/Boarding Pass has been checked and verified.
# Passenger 1255's ID/Boarding Pass has been checked and verified.
# Passenger 1254 enters Personal Scanner at 230.00.
# Passenger 1255 enters Personal Scanner at 230.00.
# Passenger 1257 enters ID Check Station at 230.00.
# Passenger 1258 enters ID Check Station at 230.00.
# Passenger 1254 completes personal scanning process.
# Passenger 1254 leaves Airport Security at 230.56.
# Passenger 1236 completes personal scanning process.
# Passenger 1236 leaves Airport Security at 230.59.
# Passenger 1247 completes personal scanning process.
# Passenger 1247 leaves Airport Security at 230.62.
# Passenger 1255 completes personal scanning process.
# Passenger 1255 leaves Airport Security at 230.68.
# Passenger 1248 completes personal scanning process.
# Passenger 1248 leaves Airport Security at 230.70.
# Passenger 1250 completes personal scanning process.
# Passenger 1250 leaves Airport Security at 230.74.
# Passenger 1245 completes personal scanning process.
# Passenger 1245 leaves Airport Security at 230.74.
# Passenger 1252 completes personal scanning process.
# Passenger 1252 leaves Airport Security at 230.76.
# Passenger 1251 completes personal scanning process.
# Passenger 1251 leaves Airport Security at 230.77.
# Passenger 1253 completes personal scanning process.
# Passenger 1253 leaves Airport Security at 230.82.
# Passenger 1246 completes personal scanning process.
# Passenger 1246 leaves Airport Security at 230.84.
# Passenger 1243 completes personal scanning process.
# Passenger 1243 leaves Airport Security at 230.89.
# Passenger 1249's ID/Boarding Pass has been checked and verified.
# Passenger 1269 arrives at the Airport Security at 231.00.
# Passenger 1257's ID/Boarding Pass has been checked and verified.
# Passenger 1249 enters Personal Scanner at 231.00.
# Passenger 1270 arrives at the Airport Security at 231.00.
# Passenger 1257 enters Personal Scanner at 231.00.
# Passenger 1259 enters ID Check Station at 231.00.
# Passenger 1260 enters ID Check Station at 231.00.
# Passenger 1259's ID/Boarding Pass has been checked and verified.
# Passenger 1260's ID/Boarding Pass has been checked and verified.
# Passenger 1259 enters Personal Scanner at 231.00.
# Passenger 1260 enters Personal Scanner at 231.00.
# Passenger 1261 enters ID Check Station at 231.00.
# Passenger 1262 enters ID Check Station at 231.00.
# Passenger 1262's ID/Boarding Pass has been checked and verified.
# Passenger 1262 enters Personal Scanner at 231.00.
# Passenger 1263 enters ID Check Station at 231.00.
# Passenger 1257 completes personal scanning process.
# Passenger 1257 leaves Airport Security at 231.67.
# Passenger 1260 completes personal scanning process.
# Passenger 1260 leaves Airport Security at 231.70.
# Passenger 1262 completes personal scanning process.
# Passenger 1262 leaves Airport Security at 231.78.
# Passenger 1259 completes personal scanning process.
# Passenger 1259 leaves Airport Security at 231.83.
# Passenger 1249 completes personal scanning process.
# Passenger 1249 leaves Airport Security at 231.97.
# Passenger 1256's ID/Boarding Pass has been checked and verified.
# Passenger 1258's ID/Boarding Pass has been checked and verified.
# Passenger 1271 arrives at the Airport Security at 232.00.
# Passenger 1263's ID/Boarding Pass has been checked and verified.
# Passenger 1256 enters Personal Scanner at 232.00.
# Passenger 1258 enters Personal Scanner at 232.00.
# Passenger 1272 arrives at the Airport Security at 232.00.
# Passenger 1263 enters Personal Scanner at 232.00.
# Passenger 1264 enters ID Check Station at 232.00.
# Passenger 1265 enters ID Check Station at 232.00.
# Passenger 1266 enters ID Check Station at 232.00.
# Passenger 1264's ID/Boarding Pass has been checked and verified.
# Passenger 1264 enters Personal Scanner at 232.00.
# Passenger 1267 enters ID Check Station at 232.00.
# Passenger 1267's ID/Boarding Pass has been checked and verified.
# Passenger 1267 enters Personal Scanner at 232.00.
# Passenger 1268 enters ID Check Station at 232.00.
# Passenger 1258 completes personal scanning process.
# Passenger 1258 leaves Airport Security at 232.64.
# Passenger 1267 completes personal scanning process.
# Passenger 1267 leaves Airport Security at 232.68.
# Passenger 1263 completes personal scanning process.
# Passenger 1263 leaves Airport Security at 232.69.
# Passenger 1264 completes personal scanning process.
# Passenger 1264 leaves Airport Security at 232.78.
# Passenger 1256 completes personal scanning process.
# Passenger 1256 leaves Airport Security at 232.82.
# Passenger 1261's ID/Boarding Pass has been checked and verified.
# Passenger 1265's ID/Boarding Pass has been checked and verified.
# Passenger 1268's ID/Boarding Pass has been checked and verified.
# Passenger 1261 enters Personal Scanner at 233.00.
# Passenger 1265 enters Personal Scanner at 233.00.
# Passenger 1268 enters Personal Scanner at 233.00.
# Passenger 1269 enters ID Check Station at 233.00.
# Passenger 1270 enters ID Check Station at 233.00.
# Passenger 1271 enters ID Check Station at 233.00.
# Passenger 1269's ID/Boarding Pass has been checked and verified.
# Passenger 1270's ID/Boarding Pass has been checked and verified.
# Passenger 1271's ID/Boarding Pass has been checked and verified.
# Passenger 1269 enters Personal Scanner at 233.00.
# Passenger 1270 enters Personal Scanner at 233.00.
# Passenger 1271 enters Personal Scanner at 233.00.
# Passenger 1272 enters ID Check Station at 233.00.
# Passenger 1269 completes personal scanning process.
# Passenger 1269 leaves Airport Security at 233.69.
# Passenger 1265 completes personal scanning process.
# Passenger 1265 leaves Airport Security at 233.87.
# Passenger 1268 completes personal scanning process.
# Passenger 1268 leaves Airport Security at 233.89.
# Passenger 1261 completes personal scanning process.
# Passenger 1261 leaves Airport Security at 233.90.
# Passenger 1271 completes personal scanning process.
# Passenger 1271 leaves Airport Security at 233.93.
# Passenger 1270 completes personal scanning process.
# Passenger 1270 leaves Airport Security at 233.99.
# Passenger 1273 arrives at the Airport Security at 234.00.
# Passenger 1266's ID/Boarding Pass has been checked and verified.
# Passenger 1272's ID/Boarding Pass has been checked and verified.
# Passenger 1273 enters ID Check Station at 234.00.
# Passenger 1266 enters Personal Scanner at 234.00.
# Passenger 1272 enters Personal Scanner at 234.00.
# Passenger 1273's ID/Boarding Pass has been checked and verified.
# Passenger 1273 enters Personal Scanner at 234.00.
# Passenger 1273 completes personal scanning process.
# Passenger 1273 leaves Airport Security at 234.67.
# Passenger 1266 completes personal scanning process.
# Passenger 1266 leaves Airport Security at 234.87.
# Passenger 1272 completes personal scanning process.
# Passenger 1272 leaves Airport Security at 234.96.
# Passenger 1274 arrives at the Airport Security at 235.00.
# Passenger 1275 arrives at the Airport Security at 235.00.
# Passenger 1274 enters ID Check Station at 235.00.
# Passenger 1276 arrives at the Airport Security at 235.00.
# Passenger 1275 enters ID Check Station at 235.00.
# Passenger 1274's ID/Boarding Pass has been checked and verified.
# Passenger 1277 arrives at the Airport Security at 235.00.
# Passenger 1276 enters ID Check Station at 235.00.
# Passenger 1274 enters Personal Scanner at 235.00.
# Passenger 1278 arrives at the Airport Security at 235.00.
# Passenger 1277 enters ID Check Station at 235.00.
# Passenger 1279 arrives at the Airport Security at 235.00.
# Passenger 1278 enters ID Check Station at 235.00.
# Passenger 1274 completes personal scanning process.
# Passenger 1274 leaves Airport Security at 235.81.
# Passenger 1275's ID/Boarding Pass has been checked and verified.
# Passenger 1276's ID/Boarding Pass has been checked and verified.
# Passenger 1277's ID/Boarding Pass has been checked and verified.
# Passenger 1280 arrives at the Airport Security at 236.00.
# Passenger 1278's ID/Boarding Pass has been checked and verified.
# Passenger 1275 enters Personal Scanner at 236.00.
# Passenger 1276 enters Personal Scanner at 236.00.
# Passenger 1277 enters Personal Scanner at 236.00.
# Passenger 1281 arrives at the Airport Security at 236.00.
# Passenger 1278 enters Personal Scanner at 236.00.
# Passenger 1279 enters ID Check Station at 236.00.
# Passenger 1280 enters ID Check Station at 236.00.
# Passenger 1281 enters ID Check Station at 236.00.
# Passenger 1279's ID/Boarding Pass has been checked and verified.
# Passenger 1280's ID/Boarding Pass has been checked and verified.
# Passenger 1279 enters Personal Scanner at 236.00.
# Passenger 1280 enters Personal Scanner at 236.00.
# Passenger 1279 completes personal scanning process.
# Passenger 1279 leaves Airport Security at 236.66.
# Passenger 1280 completes personal scanning process.
# Passenger 1280 leaves Airport Security at 236.70.
# Passenger 1277 completes personal scanning process.
# Passenger 1277 leaves Airport Security at 236.75.
# Passenger 1278 completes personal scanning process.
# Passenger 1278 leaves Airport Security at 236.82.
# Passenger 1276 completes personal scanning process.
# Passenger 1276 leaves Airport Security at 236.83.
# Passenger 1275 completes personal scanning process.
# Passenger 1275 leaves Airport Security at 236.91.
# Passenger 1282 arrives at the Airport Security at 237.00.
# Passenger 1281's ID/Boarding Pass has been checked and verified.
# Passenger 1283 arrives at the Airport Security at 237.00.
# Passenger 1282 enters ID Check Station at 237.00.
# Passenger 1281 enters Personal Scanner at 237.00.
# Passenger 1283 enters ID Check Station at 237.00.
# Passenger 1282's ID/Boarding Pass has been checked and verified.
# Passenger 1283's ID/Boarding Pass has been checked and verified.
# Passenger 1282 enters Personal Scanner at 237.00.
# Passenger 1283 enters Personal Scanner at 237.00.
# Passenger 1281 completes personal scanning process.
# Passenger 1281 leaves Airport Security at 237.76.
# Passenger 1283 completes personal scanning process.
# Passenger 1283 leaves Airport Security at 237.82.
# Passenger 1282 completes personal scanning process.
# Passenger 1282 leaves Airport Security at 237.84.
# Passenger 1284 arrives at the Airport Security at 238.00.
# Passenger 1285 arrives at the Airport Security at 238.00.
# Passenger 1284 enters ID Check Station at 238.00.
# Passenger 1286 arrives at the Airport Security at 238.00.
# Passenger 1285 enters ID Check Station at 238.00.
# Passenger 1284's ID/Boarding Pass has been checked and verified.
# Passenger 1286 enters ID Check Station at 238.00.
# Passenger 1285's ID/Boarding Pass has been checked and verified.
# Passenger 1284 enters Personal Scanner at 238.00.
# Passenger 1286's ID/Boarding Pass has been checked and verified.
# Passenger 1285 enters Personal Scanner at 238.00.
# Passenger 1286 enters Personal Scanner at 238.00.
# Passenger 1284 completes personal scanning process.
# Passenger 1284 leaves Airport Security at 238.65.
# Passenger 1285 completes personal scanning process.
# Passenger 1285 leaves Airport Security at 238.74.
# Passenger 1286 completes personal scanning process.
# Passenger 1286 leaves Airport Security at 238.78.
# Passenger 1287 arrives at the Airport Security at 239.00.
# Passenger 1288 arrives at the Airport Security at 239.00.
# Passenger 1287 enters ID Check Station at 239.00.
# Passenger 1289 arrives at the Airport Security at 239.00.
# Passenger 1288 enters ID Check Station at 239.00.
# Passenger 1290 arrives at the Airport Security at 239.00.
# Passenger 1289 enters ID Check Station at 239.00.
# Passenger 1288's ID/Boarding Pass has been checked and verified.
# Passenger 1290 enters ID Check Station at 239.00.
# Passenger 1288 enters Personal Scanner at 239.00.
# Passenger 1290's ID/Boarding Pass has been checked and verified.
# Passenger 1290 enters Personal Scanner at 239.00.
# Passenger 1288 completes personal scanning process.
# Passenger 1288 leaves Airport Security at 239.91.
# Passenger 1290 completes personal scanning process.
# Passenger 1290 leaves Airport Security at 239.94.

# %%
np.mean(wait_times)
# Out:
# 12.896051817269358

# %%
# In order to keep average wait times below 15 minutes for arrivals of 5 passengers per minute, the simulation
# above determines one possible combination is 4 ID Check Stations and 2 Personal Check Scanners. However,
# the combinations can vary. It is also worth noting that adding ID Checking Stations seems to reduce wait times
# a greater degree more than personal scanners.
